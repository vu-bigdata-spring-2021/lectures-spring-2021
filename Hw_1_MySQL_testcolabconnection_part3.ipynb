# %% [markdown]
# <a href="https://colab.research.google.com/github/vu-bigdata-spring-2021/lectures-spring-2021/blob/main/Hw_1_MySQL_testcolabconnection_part3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Get MySQL python Module (note we use python 3 by default)

# %%
# !pip install pymysql
# Out:
# Requirement already satisfied: pymysql in /usr/local/lib/python3.6/dist-packages (1.0.1)

# %% [markdown]
# Create the DB connection class and update the parameters for your database

# %%
import pymysql


class DB:
    def __init__(self):
        try:
          self.conn = pymysql.connect(
              user = "admin",
              password = "adminadmin",
              host="database-1.cjcbghqlwnpl.us-east-1.rds.amazonaws.com",
              database='lahman'
          )

        except Exception as e:
            print("I am unable to connect to the database - bye " + str(e))
            exit()
        print('Got a DB connection!- hurray')
        self.cur = self.conn.cursor()

    def cursor(self):
        return self.cur

    def getNewCursor(self):
        return self.conn.cursor()

    def connection(self):
        return self.conn

    def query(self, q):
        self.cur.execute(q)
        try:
          return self.cur.fetchall()
        except Exception as e:
          print('no result to return')
          return

# %% [markdown]
# Run a sample Query.

# %%
db1 = DB()

q = 'use lahman;'#@param {type:"string"}
db1.query(q)
#db1.connection().commit()
q = 'show tables;'#@param {type:"string"}
res=db1.query(q)
#db1.connection().commit()
print('Success! I ran a query and got {} results'.format(len(db1.query(q))))
print(res)

q = 'select * from lahman.allstarfull;'#@param {type:"string"}
res=db1.query(q)
print('Success! I ran a query and got {} results'.format(len(db1.query(q))))
print(res)

mycursor = db1.cursor()
mycursor.execute("use lahman;")
mycursor.execute("show tables;")

myresult = mycursor.fetchall()
print('Success! I ran a query and got {} results'.format(len(myresult)))
for x in myresult:
  print(x)
# Out:
# Got a DB connection!- hurray
# Success! I ran a query and got 25 results
# (('allstarfull',), ('appearances',), ('awardsmanagers',), ('awardsplayers',), ('awardssharemanagers',), ('awardsshareplayers',), ('batting',), ('battingpost',), ('fielding',), ('fieldingof',), ('fieldingpost',), ('halloffame',), ('hofold',), ('managers',), ('managershalf',), ('master',), ('pitching',), ('pitchingpost',), ('salaries',), ('schools',), ('schoolsplayers',), ('seriespost',), ('teams',), ('teamsfranchises',), ('teamshalf',))
# Success! I ran a query and got 4834 results
# (('aaronha01', 1955, 0, 'NLS195507120', 'ML1', 'NL', 1, None), ('aaronha01', 1956, 0, 'ALS195607100', 'ML1', 'NL', 1, None), ('aaronha01', 1957, 0, 'NLS195707090', 'ML1', 'NL', 1, 9), ('aaronha01', 1958, 0, 'ALS195807080', 'ML1', 'NL', 1, 9), ('aaronha01', 1959, 1, 'NLS195907070', 'ML1', 'NL', 1, 9), ('aaronha01', 1959, 2, 'NLS195908030', 'ML1', 'NL', 1, 9), ('aaronha01', 1960, 1, 'ALS196007110', 'ML1', 'NL', 1, 9), ('aaronha01', 1960, 2, 'ALS196007130', 'ML1', 'NL', 1, 9), ('aaronha01', 1961, 1, 'NLS196107110', 'ML1', 'NL', 1, None), ('aaronha01', 1961, 2, 'ALS196107310', 'ML1', 'NL', 1, None), ('aaronha01', 1962, 1, 'ALS196207100', 'ML1', 'NL', 0, None), ('aaronha01', 1962, 2, 'NLS196207300', 'ML1', 'NL', 1, None), ('aaronha01', 1963, 0, 'ALS196307090', 'ML1', 'NL', 1, 9), ('aaronha01', 1964, 0, 'NLS196407070', 'ML1', 'NL', 1, None), ('aaronha01', 1965, 0, 'ALS196507130', 'ML1', 'NL', 1, 9), ('aaronha01', 1966, 0, 'NLS196607120', 'ATL', 'NL', 1, 7), ('aaronha01', 1967, 0, 'ALS196707110', 'ATL', 'NL', 1, 8), ('aaronha01', 1968, 0, 'NLS196807090', 'ATL', 'NL', 1, 9), ('aaronha01', 1969, 0, 'ALS196907230', 'ATL', 'NL', 1, 9), ('aaronha01', 1970, 0, 'NLS197007140', 'ATL', 'NL', 1, 9), ('aaronha01', 1971, 0, 'ALS197107130', 'ATL', 'NL', 1, 9), ('aaronha01', 1972, 0, 'NLS197207250', 'ATL', 'NL', 1, 9), ('aaronha01', 1973, 0, 'ALS197307240', 'ATL', 'NL', 1, 3), ('aaronha01', 1974, 0, 'NLS197407230', 'ATL', 'NL', 1, 9), ('aaronha01', 1975, 0, 'ALS197507150', 'ML4', 'AL', 1, None), ('aasedo01', 1986, 0, 'NLS198607150', 'BAL', 'AL', 1, None), ('abreubo01', 2004, 0, 'NLS200407130', 'PHI', 'NL', 1, None), ('abreubo01', 2005, 0, 'ALS200507120', 'PHI', 'NL', 1, 9), ('adamsac01', 1943, 0, 'ALS194307130', 'NY1', 'NL', 0, None), ('adcocjo01', 1960, 1, 'ALS196007110', 'ML1', 'NL', 1, 3), ('adcocjo01', 1960, 2, 'ALS196007130', 'ML1', 'NL', 1, 3), ('ageeto01', 1966, 0, 'NLS196607120', 'CHA', 'AL', 1, None), ('ageeto01', 1967, 0, 'ALS196707110', 'CHA', 'AL', 1, None), ('aguilri01', 1991, 0, 'ALS199107090', 'MIN', 'AL', 1, None), ('aguilri01', 1992, 0, 'NLS199207140', 'MIN', 'AL', 1, None), ('aguilri01', 1993, 0, 'ALS199307130', 'MIN', 'AL', 1, None), ('aguirha01', 1962, 1, 'ALS196207100', 'DET', 'AL', 0, None), ('aguirha01', 1962, 2, 'NLS196207300', 'DET', 'AL', 1, None), ('alexado01', 1988, 0, 'NLS198807120', 'DET', 'AL', 0, None), ('alfoned01', 2000, 0, 'NLS200007110', 'NYN', 'NL', 1, None), ('allendi01', 1965, 0, 'ALS196507130', 'PHI', 'NL', 1, 5), ('allendi01', 1966, 0, 'NLS196607120', 'PHI', 'NL', 1, None), ('allendi01', 1967, 0, 'ALS196707110', 'PHI', 'NL', 1, 5), ('allendi01', 1970, 0, 'NLS197007140', 'SLN', 'NL', 1, 3), ('allendi01', 1972, 0, 'NLS197207250', 'CHA', 'AL', 1, 3), ('allendi01', 1973, 0, 'ALS197307240', 'CHA', 'AL', 0, None), ('allendi01', 1974, 0, 'NLS197407230', 'CHA', 'AL', 1, 3), ('allenjo02', 1938, 0, 'NLS193807060', 'CLE', 'AL', 1, None), ('alleyge01', 1967, 0, 'ALS196707110', 'PIT', 'NL', 1, 6), ('alleyge01', 1968, 0, 'NLS196807090', 'PIT', 'NL', 0, None), ('allisbo01', 1959, 2, 'NLS195908030', 'WS1', 'AL', 0, None), ('allisbo01', 1963, 0, 'ALS196307090', 'MIN', 'AL', 1, None), ('allisbo01', 1964, 0, 'NLS196407070', 'MIN', 'AL', 1, 3), ('alomaro01', 1990, 0, 'NLS199007100', 'SDN', 'NL', 1, None), ('alomaro01', 1991, 0, 'ALS199107090', 'TOR', 'AL', 1, 4), ('alomaro01', 1992, 0, 'NLS199207140', 'TOR', 'AL', 1, 4), ('alomaro01', 1993, 0, 'ALS199307130', 'TOR', 'AL', 1, 4), ('alomaro01', 1994, 0, 'NLS199407120', 'TOR', 'AL', 1, 4), ('alomaro01', 1995, 0, 'ALS199507110', 'TOR', 'AL', 1, None), ('alomaro01', 1996, 0, 'NLS199607090', 'BAL', 'AL', 1, 4), ('alomaro01', 1997, 0, 'ALS199707080', 'BAL', 'AL', 1, 4), ('alomaro01', 1998, 0, 'NLS199807070', 'BAL', 'AL', 1, 4), ('alomaro01', 1999, 0, 'ALS199907130', 'CLE', 'AL', 1, 4), ('alomaro01', 2000, 0, 'NLS200007110', 'CLE', 'AL', 1, 4), ('alomaro01', 2001, 0, 'ALS200107100', 'CLE', 'AL', 1, None), ('alomasa01', 1970, 0, 'NLS197007140', 'CAL', 'AL', 1, None), ('alomasa02', 1990 ...
# Success! I ran a query and got 25 results
# ('allstarfull',)
# ('appearances',)
# ('awardsmanagers',)
# ('awardsplayers',)
# ('awardssharemanagers',)
# ('awardsshareplayers',)
# ('batting',)
# ('battingpost',)
# ('fielding',)
# ('fieldingof',)
# ('fieldingpost',)
# ('halloffame',)
# ('hofold',)
# ('managers',)
# ('managershalf',)
# ('master',)
# ('pitching',)
# ('pitchingpost',)
# ('salaries',)
# ('schools',)
# ('schoolsplayers',)
# ('seriespost',)
# ('teams',)
# ('teamsfranchises',)
# ('teamshalf',)
